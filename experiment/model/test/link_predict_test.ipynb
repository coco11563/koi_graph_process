# %%
import importlib

# %%
import gc
import sys
import time
sys.path.append("/home/shaow/jupyter_base/pycharm_001")
base = "/home/shaow/jupyter_base/pycharm_001"
import torch
import experiment.model.dglGCNModel as models
import graph_process as G
import obj.GraphBase as GB
import utils

# %%
appid_edge, appid_ros_edge, appid_app_edge, app_ros_edge, app_kw_edge, \
           id_index_map ,index_id_map, index_keyword_map, index_ros_map, index_app_map , \
           app_dict = G.process_year_graph(2019)



gb_2019 = GB.GraphBase(appid_edge, appid_ros_edge, appid_app_edge, app_ros_edge, app_kw_edge,
           id_index_map, index_id_map, index_ros_map, index_app_map, index_keyword_map ,
           app_dict)
# Out:
# 8.0.19
# 10
# socket 10.0.82.237:3306
# done init 3564 nodes from apply id
# 244800
# done init 615669 nodes from application

# %%
print(gb_2019.node_count())
# Out:
# 615670

# %%
# importlib.reload(G)
gb = gb_2019.get_split_appid_map('F01')
t_data = G.get_graph_edges(gb)

# %%
# index_keyword_map[27997]
# gb.ikm

# %%
# t_data = load_data('wn18')
# entities: 14951
# relations: 1345
# edges: 483142
# num_nodes = t_data.num_nodes
train_data = t_data.train
valid_data = t_data.validation
test_data = t_data.test
# num_rels = t_data.num_rels
num_nodes = gb.node_count()
num_rels = gb.rel_count()

# %%
print(test_data.shape)
print(train_data.shape)
print(valid_data.shape)
# Out:
# (3748, 3)
# (29771, 3)
# (3738, 3)

# %%
# test_graph, test_node_id, test_rel, test_norm = G.make_test_graph(test_data, num_rels)
# test_node_id = torch.from_numpy(test_node_id)
# test_norm = torch.from_numpy(test_norm)
# # test_rel = torch.from_numpy(test_rel)
# test_edge_norm = node_norm_to_edge_norm(test_graph, test_norm.view(-1, 1))
test_graph, test_rel, test_norm = utils.build_test_graph(
        num_nodes, num_rels, train_data)
test_deg = test_graph.in_degrees(
            range(test_graph.number_of_nodes())).float().view(-1,1)
test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
test_rel = torch.from_numpy(test_rel)
test_norm = models.node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))
# Out:
# Test graph:
# # nodes: 20518, # edges: 59542
# /home/shaow/jupyter_base/pycharm_001/utils.py:130: RuntimeWarning: divide by zero encountered in true_divide
#   norm = 1.0 / in_deg

# %%
test_data = torch.from_numpy(test_data)
use_cuda = torch.cuda.is_available()

# %%
if use_cuda:
    torch.cuda.set_device('cuda:0')

# %%
model = models.LinkPredict(num_nodes,
                        256,
                        num_rels,
                    #="number of weight blocks for each relation"
                        num_bases=100,
                    # number of propagation rounds
                    # 3 because the trans road
                        num_hidden_layers=3,
                        dropout=0.2,
                        use_cuda=use_cuda,
                    # regularization weight
                        reg_param=0.01)

# %%
# test_graph, test_rel, test_norm = utils.build_test_graph(
#         num_nodes, num_rels, train_data)
# test_deg = test_graph.in_degrees(
#             range(test_graph.number_of_nodes())).float().view(-1,1)
# test_node_id = torch.arange(0, num_nodes, dtype=torch.long).view(-1, 1)
# test_rel = torch.from_numpy(test_rel)
# test_norm = node_norm_to_edge_norm(test_graph, torch.from_numpy(test_norm).view(-1, 1))
# print(test_node_id)

# %%
if use_cuda:
    model.cuda()

# build adj list and calculate degrees for sampling
adj_list, degrees = utils.get_adj_and_degrees(num_nodes, train_data)

# optimizer
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)

model_state_file = 'model_state.pth'
forward_time = []
backward_time = []

# training loop
print("start training...")

epoch = 0
best_mrr = 0
# Out:
# start training...

# %%
while True:
    model.train()
    epoch += 1
    # perform edge neighborhood sampling to generate training graph and data
    g, node_id, edge_type, node_norm, data, labels = \
        utils.generate_sampled_graph_and_labels(
            train_data, sample_size=10000, split_size=0.5,
            num_rels=num_rels, adj_list=adj_list, degrees=degrees, negative_rate=5,
            sampler='uniform')
    # print("Done edge sampling")
    # set node/edge feature
    node_id = torch.from_numpy(node_id).view(-1, 1).long()
    edge_type = torch.from_numpy(edge_type)
    edge_norm = models.node_norm_to_edge_norm(g, torch.from_numpy(node_norm).view(-1, 1))
    data, labels = torch.from_numpy(data), torch.from_numpy(labels)
    deg = g.in_degrees(range(g.number_of_nodes())).float().view(-1, 1)
    if use_cuda:
        node_id, deg = node_id.cuda(), deg.cuda()
        edge_type, edge_norm = edge_type.cuda(), edge_norm.cuda()
        data, labels = data.cuda(), labels.cuda()

    t0 = time.time()
    embed = model(g, node_id, edge_type, edge_norm)
    print(embed.shape)
    loss = model.get_loss(g, embed, data, labels)
    t1 = time.time()
    loss.backward()
    # grade norm = 1.0
    torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0) # clip gradients
    optimizer.step()
    t2 = time.time()

    forward_time.append(t1 - t0)
    backward_time.append(t2 - t1)
    if epoch % 25 == 0:
        print("Epoch {:04d} | Loss {:.4f} | Best MRR {:.4f} | Forward {:.4f}s | Backward {:.4f}s".
          format(epoch, loss.item(), best_mrr, forward_time[-1], backward_time[-1]))

    optimizer.zero_grad()

    # validation
    if epoch % 100 == 0:
        # gc.collect()
        # perform validation on CPU because full graph is too large
        if use_cuda:
            model.cpu()
        model.eval()
        print("start eval")
        print(test_graph)
        # if use_cuda:
        #     test_graph = test_graph.to('cuda:0')
        #     test_node_id, test_rel, test_norm = test_node_id.cuda(), test_rel.cuda(), test_norm.cuda()
        # embed = model.embedding.embedding
        # embed = embed(test_node_id)
        embed = model(test_graph, test_node_id, test_rel, test_norm)
        # torch.cuda.empty_cache()
        # gc.collect()
        # args.eval_batch_size = 500
        mrr = utils.calc_mrr(embed, model.w_relation, test_data,
                             hits=[1, 3, 10], eval_bz=500)
        # save best model
        if mrr < best_mrr:
            # min train epoch = 6000
            if epoch >= 6000:
                break
        else:
            best_mrr = mrr
            torch.save({'state_dict': model.state_dict(), 'epoch': epoch},
                       model_state_file)
        if use_cuda:
            model.cuda()
# Out:
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10143
# # sampled edges: 10000
# # nodes: 10143, # edges: 10000
# torch.Size([10143, 256])
# # sampled nodes: 10322
# # sampled edges: 10000
# # nodes: 10322, # edges: 10000
# torch.Size([10322, 256])
# # sampled nodes: 10234
# # sampled edges: 10000
# # nodes: 10234, # edges: 10000
# torch.Size([10234, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# Epoch 0010 | Loss 0.5627 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0749s
# # sampled nodes: 10229
# # sampled edges: 10000
# # nodes: 10229, # edges: 10000
# torch.Size([10229, 256])
# # sampled nodes: 10316
# # sampled edges: 10000
# # nodes: 10316, # edges: 10000
# torch.Size([10316, 256])
# # sampled nodes: 10156
# # sampled edges: 10000
# # nodes: 10156, # edges: 10000
# torch.Size([10156, 256])
# # sampled nodes: 10323
# # sampled edges: 10000
# # nodes: 10323, # edges: 10000
# torch.Size([10323, 256])
# # sampled nodes: 10190
# # sampled edges: 10000
# # nodes: 10190, # edges: 10000
# torch.Size([10190, 256])
# # sampled nodes: 10335
# # sampled edges: 10000
# # nodes: 10335, # edges: 10000
# torch.Size([10335, 256])
# # sampled nodes: 10201
# # sampled edges: 10000
# # nodes: 10201, # edges: 10000
# torch.Size([10201, 256])
# # sampled nodes: 10300
# # sampled edges: 10000
# # nodes: 10300, # edges: 10000
# torch.Size([10300, 256])
# # sampled nodes: 10303
# # sampled edges: 10000
# # nodes: 10303, # edges: 10000
# torch.Size([10303, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# Epoch 0020 | Loss 0.4633 | Best MRR 0.0000 | Forward 0.0294s | Backward 0.0749s
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# # sampled nodes: 10205
# # sampled edges: 10000
# # nodes: 10205, # edges: 10000
# torch.Size([10205, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10313
# # sampled edges: 10000
# # nodes: 10313, # edges: 10000
# torch.Size([10313, 256])
# # sampled nodes: 10230
# # sampled edges: 10000
# # nodes: 10230, # edges: 10000
# torch.Size([10230, 256])
# # sampled nodes: 10197
# # sampled edges: 10000
# # nodes: 10197, # edges: 10000
# torch.Size([10197, 256])
# # sampled nodes: 10261
# # sampled edges: 10000
# # nodes: 10261, # edges: 10000
# torch.Size([10261, 256])
# # sampled nodes: 10229
# # sampled edges: 10000
# # nodes: 10229, # edges: 10000
# torch.Size([10229, 256])
# # sampled nodes: 10217
# # sampled edges: 10000
# # nodes: 10217, # edges: 10000
# torch.Size([10217, 256])
# # sampled nodes: 10303
# # sampled edges: 10000
# # nodes: 10303, # edges: 10000
# torch.Size([10303, 256])
# Epoch 0030 | Loss 0.4159 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0760s
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10218
# # sampled edges: 10000
# # nodes: 10218, # edges: 10000
# torch.Size([10218, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# Epoch 0040 | Loss 0.3890 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0756s
# # sampled nodes: 10187
# # sampled edges: 10000
# # nodes: 10187, # edges: 10000
# torch.Size([10187, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10273
# # sampled edges: 10000
# # nodes: 10273, # edges: 10000
# torch.Size([10273, 256])
# # sampled nodes: 10230
# # sampled edges: 10000
# # nodes: 10230, # edges: 10000
# torch.Size([10230, 256])
# # sampled nodes: 10248
# # sampled edges: 10000
# # nodes: 10248, # edges: 10000
# torch.Size([10248, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10265
# # sampled edges: 10000
# # nodes: 10265, # edges: 10000
# torch.Size([10265, 256])
# # sampled nodes: 10338
# # sampled edges: 10000
# # nodes: 10338, # edges: 10000
# torch.Size([10338, 256])
# # sampled nodes: 10197
# # sampled edges: 10000
# # nodes: 10197, # edges: 10000
# torch.Size([10197, 256])
# Epoch 0050 | Loss 0.3684 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0762s
# # sampled nodes: 10267
# # sampled edges: 10000
# # nodes: 10267, # edges: 10000
# torch.Size([10267, 256])
# # sampled nodes: 10184
# # sampled edges: 10000
# # nodes: 10184, # edges: 10000
# torch.Size([10184, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# # sampled nodes: 10213
# # sampled edges: 10000
# # nodes: 10213, # edges: 10000
# torch.Size([10213, 256])
# # sampled nodes: 10236
# # sampled edges: 10000
# # nodes: 10236, # edges: 10000
# torch.Size([10236, 256])
# # sampled nodes: 10200
# # sampled edges: 10000
# # nodes: 10200, # edges: 10000
# torch.Size([10200, 256])
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# # sampled nodes: 10200
# # sampled edges: 10000
# # nodes: 10200, # edges: 10000
# torch.Size([10200, 256])
# # sampled nodes: 10236
# # sampled edges: 10000
# # nodes: 10236, # edges: 10000
# torch.Size([10236, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# Epoch 0060 | Loss 0.3563 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0744s
# # sampled nodes: 10285
# # sampled edges: 10000
# # nodes: 10285, # edges: 10000
# torch.Size([10285, 256])
# # sampled nodes: 10289
# # sampled edges: 10000
# # nodes: 10289, # edges: 10000
# torch.Size([10289, 256])
# # sampled nodes: 10253
# # sampled edges: 10000
# # nodes: 10253, # edges: 10000
# torch.Size([10253, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10228
# # sampled edges: 10000
# # nodes: 10228, # edges: 10000
# torch.Size([10228, 256])
# # sampled nodes: 10224
# # sampled edges: 10000
# # nodes: 10224, # edges: 10000
# torch.Size([10224, 256])
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# # sampled nodes: 10173
# # sampled edges: 10000
# # nodes: 10173, # edges: 10000
# torch.Size([10173, 256])
# # sampled nodes: 10164
# # sampled edges: 10000
# # nodes: 10164, # edges: 10000
# torch.Size([10164, 256])
# # sampled nodes: 10317
# # sampled edges: 10000
# # nodes: 10317, # edges: 10000
# torch.Size([10317, 256])
# Epoch 0070 | Loss 0.3482 | Best MRR 0.0000 | Forward 0.0294s | Backward 0.0744s
# # sampled nodes: 10218
# # sampled edges: 10000
# # nodes: 10218, # edges: 10000
# torch.Size([10218, 256])
# # sampled nodes: 10285
# # sampled edges: 10000
# # nodes: 10285, # edges: 10000
# torch.Size([10285, 256])
# # sampled nodes: 10218
# # sampled edges: 10000
# # nodes: 10218, # edges: 10000
# torch.Size([10218, 256])
# # sampled nodes: 10302
# # sampled edges: 10000
# # nodes: 10302, # edges: 10000
# torch.Size([10302, 256])
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10173
# # sampled edges: 10000
# # nodes: 10173, # edges: 10000
# torch.Size([10173, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10308
# # sampled edges: 10000
# # nodes: 10308, # edges: 10000
# torch.Size([10308, 256])
# # sampled nodes: 10361
# # sampled edges: 10000
# # nodes: 10361, # edges: 10000
# torch.Size([10361, 256])
# Epoch 0080 | Loss 0.3415 | Best MRR 0.0000 | Forward 0.0294s | Backward 0.0751s
# # sampled nodes: 10198
# # sampled edges: 10000
# # nodes: 10198, # edges: 10000
# torch.Size([10198, 256])
# # sampled nodes: 10249
# # sampled edges: 10000
# # nodes: 10249, # edges: 10000
# torch.Size([10249, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10201
# # sampled edges: 10000
# # nodes: 10201, # edges: 10000
# torch.Size([10201, 256])
# # sampled nodes: 10263
# # sampled edges: 10000
# # nodes: 10263, # edges: 10000
# torch.Size([10263, 256])
# # sampled nodes: 10249
# # sampled edges: 10000
# # nodes: 10249, # edges: 10000
# torch.Size([10249, 256])
# # sampled nodes: 10222
# # sampled edges: 10000
# # nodes: 10222, # edges: 10000
# torch.Size([10222, 256])
# # sampled nodes: 10236
# # sampled edges: 10000
# # nodes: 10236, # edges: 10000
# torch.Size([10236, 256])
# # sampled nodes: 10276
# # sampled edges: 10000
# # nodes: 10276, # edges: 10000
# torch.Size([10276, 256])
# # sampled nodes: 10283
# # sampled edges: 10000
# # nodes: 10283, # edges: 10000
# torch.Size([10283, 256])
# Epoch 0090 | Loss 0.3354 | Best MRR 0.0000 | Forward 0.0294s | Backward 0.0752s
# # sampled nodes: 10205
# # sampled edges: 10000
# # nodes: 10205, # edges: 10000
# torch.Size([10205, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10217
# # sampled edges: 10000
# # nodes: 10217, # edges: 10000
# torch.Size([10217, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10343
# # sampled edges: 10000
# # nodes: 10343, # edges: 10000
# torch.Size([10343, 256])
# # sampled nodes: 10217
# # sampled edges: 10000
# # nodes: 10217, # edges: 10000
# torch.Size([10217, 256])
# # sampled nodes: 10233
# # sampled edges: 10000
# # nodes: 10233, # edges: 10000
# torch.Size([10233, 256])
# # sampled nodes: 10240
# # sampled edges: 10000
# # nodes: 10240, # edges: 10000
# torch.Size([10240, 256])
# # sampled nodes: 10239
# # sampled edges: 10000
# # nodes: 10239, # edges: 10000
# torch.Size([10239, 256])
# Epoch 0100 | Loss 0.3343 | Best MRR 0.0000 | Forward 0.0295s | Backward 0.0749s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.012444
# Hits (raw) @ 1: 0.003735
# Hits (raw) @ 3: 0.009872
# Hits (raw) @ 10: 0.027615
# # sampled nodes: 10228
# # sampled edges: 10000
# # nodes: 10228, # edges: 10000
# torch.Size([10228, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# # sampled nodes: 10271
# # sampled edges: 10000
# # nodes: 10271, # edges: 10000
# torch.Size([10271, 256])
# # sampled nodes: 10170
# # sampled edges: 10000
# # nodes: 10170, # edges: 10000
# torch.Size([10170, 256])
# # sampled nodes: 10309
# # sampled edges: 10000
# # nodes: 10309, # edges: 10000
# torch.Size([10309, 256])
# # sampled nodes: 10201
# # sampled edges: 10000
# # nodes: 10201, # edges: 10000
# torch.Size([10201, 256])
# # sampled nodes: 10243
# # sampled edges: 10000
# # nodes: 10243, # edges: 10000
# torch.Size([10243, 256])
# Epoch 0110 | Loss 0.3301 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0752s
# # sampled nodes: 10269
# # sampled edges: 10000
# # nodes: 10269, # edges: 10000
# torch.Size([10269, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10313
# # sampled edges: 10000
# # nodes: 10313, # edges: 10000
# torch.Size([10313, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# # sampled nodes: 10228
# # sampled edges: 10000
# # nodes: 10228, # edges: 10000
# torch.Size([10228, 256])
# # sampled nodes: 10280
# # sampled edges: 10000
# # nodes: 10280, # edges: 10000
# torch.Size([10280, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# # sampled nodes: 10151
# # sampled edges: 10000
# # nodes: 10151, # edges: 10000
# torch.Size([10151, 256])
# Epoch 0120 | Loss 0.3226 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0747s
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# # sampled nodes: 10276
# # sampled edges: 10000
# # nodes: 10276, # edges: 10000
# torch.Size([10276, 256])
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10165
# # sampled edges: 10000
# # nodes: 10165, # edges: 10000
# torch.Size([10165, 256])
# # sampled nodes: 10207
# # sampled edges: 10000
# # nodes: 10207, # edges: 10000
# torch.Size([10207, 256])
# # sampled nodes: 10223
# # sampled edges: 10000
# # nodes: 10223, # edges: 10000
# torch.Size([10223, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10178
# # sampled edges: 10000
# # nodes: 10178, # edges: 10000
# torch.Size([10178, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# Epoch 0130 | Loss 0.3157 | Best MRR 0.0124 | Forward 0.0294s | Backward 0.0758s
# # sampled nodes: 10279
# # sampled edges: 10000
# # nodes: 10279, # edges: 10000
# torch.Size([10279, 256])
# # sampled nodes: 10210
# # sampled edges: 10000
# # nodes: 10210, # edges: 10000
# torch.Size([10210, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10260
# # sampled edges: 10000
# # nodes: 10260, # edges: 10000
# torch.Size([10260, 256])
# # sampled nodes: 10311
# # sampled edges: 10000
# # nodes: 10311, # edges: 10000
# torch.Size([10311, 256])
# # sampled nodes: 10203
# # sampled edges: 10000
# # nodes: 10203, # edges: 10000
# torch.Size([10203, 256])
# # sampled nodes: 10236
# # sampled edges: 10000
# # nodes: 10236, # edges: 10000
# torch.Size([10236, 256])
# # sampled nodes: 10240
# # sampled edges: 10000
# # nodes: 10240, # edges: 10000
# torch.Size([10240, 256])
# # sampled nodes: 10295
# # sampled edges: 10000
# # nodes: 10295, # edges: 10000
# torch.Size([10295, 256])
# # sampled nodes: 10303
# # sampled edges: 10000
# # nodes: 10303, # edges: 10000
# torch.Size([10303, 256])
# Epoch 0140 | Loss 0.3126 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0763s
# # sampled nodes: 10179
# # sampled edges: 10000
# # nodes: 10179, # edges: 10000
# torch.Size([10179, 256])
# # sampled nodes: 10263
# # sampled edges: 10000
# # nodes: 10263, # edges: 10000
# torch.Size([10263, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10172
# # sampled edges: 10000
# # nodes: 10172, # edges: 10000
# torch.Size([10172, 256])
# # sampled nodes: 10292
# # sampled edges: 10000
# # nodes: 10292, # edges: 10000
# torch.Size([10292, 256])
# # sampled nodes: 10282
# # sampled edges: 10000
# # nodes: 10282, # edges: 10000
# torch.Size([10282, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10277
# # sampled edges: 10000
# # nodes: 10277, # edges: 10000
# torch.Size([10277, 256])
# # sampled nodes: 10234
# # sampled edges: 10000
# # nodes: 10234, # edges: 10000
# torch.Size([10234, 256])
# Epoch 0150 | Loss 0.3078 | Best MRR 0.0124 | Forward 0.0294s | Backward 0.0749s
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10299
# # sampled edges: 10000
# # nodes: 10299, # edges: 10000
# torch.Size([10299, 256])
# # sampled nodes: 10150
# # sampled edges: 10000
# # nodes: 10150, # edges: 10000
# torch.Size([10150, 256])
# # sampled nodes: 10202
# # sampled edges: 10000
# # nodes: 10202, # edges: 10000
# torch.Size([10202, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10318
# # sampled edges: 10000
# # nodes: 10318, # edges: 10000
# torch.Size([10318, 256])
# # sampled nodes: 10301
# # sampled edges: 10000
# # nodes: 10301, # edges: 10000
# torch.Size([10301, 256])
# # sampled nodes: 10310
# # sampled edges: 10000
# # nodes: 10310, # edges: 10000
# torch.Size([10310, 256])
# # sampled nodes: 10219
# # sampled edges: 10000
# # nodes: 10219, # edges: 10000
# torch.Size([10219, 256])
# # sampled nodes: 10299
# # sampled edges: 10000
# # nodes: 10299, # edges: 10000
# torch.Size([10299, 256])
# Epoch 0160 | Loss 0.3018 | Best MRR 0.0124 | Forward 0.0296s | Backward 0.0735s
# # sampled nodes: 10317
# # sampled edges: 10000
# # nodes: 10317, # edges: 10000
# torch.Size([10317, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# # sampled nodes: 10339
# # sampled edges: 10000
# # nodes: 10339, # edges: 10000
# torch.Size([10339, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10204
# # sampled edges: 10000
# # nodes: 10204, # edges: 10000
# torch.Size([10204, 256])
# # sampled nodes: 10319
# # sampled edges: 10000
# # nodes: 10319, # edges: 10000
# torch.Size([10319, 256])
# # sampled nodes: 10280
# # sampled edges: 10000
# # nodes: 10280, # edges: 10000
# torch.Size([10280, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# Epoch 0170 | Loss 0.2960 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0758s
# # sampled nodes: 10275
# # sampled edges: 10000
# # nodes: 10275, # edges: 10000
# torch.Size([10275, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10261
# # sampled edges: 10000
# # nodes: 10261, # edges: 10000
# torch.Size([10261, 256])
# # sampled nodes: 10243
# # sampled edges: 10000
# # nodes: 10243, # edges: 10000
# torch.Size([10243, 256])
# # sampled nodes: 10298
# # sampled edges: 10000
# # nodes: 10298, # edges: 10000
# torch.Size([10298, 256])
# # sampled nodes: 10293
# # sampled edges: 10000
# # nodes: 10293, # edges: 10000
# torch.Size([10293, 256])
# # sampled nodes: 10155
# # sampled edges: 10000
# # nodes: 10155, # edges: 10000
# torch.Size([10155, 256])
# # sampled nodes: 10253
# # sampled edges: 10000
# # nodes: 10253, # edges: 10000
# torch.Size([10253, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10207
# # sampled edges: 10000
# # nodes: 10207, # edges: 10000
# torch.Size([10207, 256])
# Epoch 0180 | Loss 0.2898 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0740s
# # sampled nodes: 10213
# # sampled edges: 10000
# # nodes: 10213, # edges: 10000
# torch.Size([10213, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10209
# # sampled edges: 10000
# # nodes: 10209, # edges: 10000
# torch.Size([10209, 256])
# # sampled nodes: 10178
# # sampled edges: 10000
# # nodes: 10178, # edges: 10000
# torch.Size([10178, 256])
# # sampled nodes: 10250
# # sampled edges: 10000
# # nodes: 10250, # edges: 10000
# torch.Size([10250, 256])
# # sampled nodes: 10186
# # sampled edges: 10000
# # nodes: 10186, # edges: 10000
# torch.Size([10186, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10229
# # sampled edges: 10000
# # nodes: 10229, # edges: 10000
# torch.Size([10229, 256])
# # sampled nodes: 10332
# # sampled edges: 10000
# # nodes: 10332, # edges: 10000
# torch.Size([10332, 256])
# # sampled nodes: 10263
# # sampled edges: 10000
# # nodes: 10263, # edges: 10000
# torch.Size([10263, 256])
# Epoch 0190 | Loss 0.2874 | Best MRR 0.0124 | Forward 0.0295s | Backward 0.0745s
# # sampled nodes: 10183
# # sampled edges: 10000
# # nodes: 10183, # edges: 10000
# torch.Size([10183, 256])
# # sampled nodes: 10243
# # sampled edges: 10000
# # nodes: 10243, # edges: 10000
# torch.Size([10243, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10284
# # sampled edges: 10000
# # nodes: 10284, # edges: 10000
# torch.Size([10284, 256])
# # sampled nodes: 10279
# # sampled edges: 10000
# # nodes: 10279, # edges: 10000
# torch.Size([10279, 256])
# # sampled nodes: 10223
# # sampled edges: 10000
# # nodes: 10223, # edges: 10000
# torch.Size([10223, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10304
# # sampled edges: 10000
# # nodes: 10304, # edges: 10000
# torch.Size([10304, 256])
# # sampled nodes: 10240
# # sampled edges: 10000
# # nodes: 10240, # edges: 10000
# torch.Size([10240, 256])
# # sampled nodes: 10254
# # sampled edges: 10000
# # nodes: 10254, # edges: 10000
# torch.Size([10254, 256])
# Epoch 0200 | Loss 0.2807 | Best MRR 0.0124 | Forward 0.0296s | Backward 0.0728s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.014455
# Hits (raw) @ 1: 0.005870
# Hits (raw) @ 3: 0.009338
# Hits (raw) @ 10: 0.026814
# # sampled nodes: 10220
# # sampled edges: 10000
# # nodes: 10220, # edges: 10000
# torch.Size([10220, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10169
# # sampled edges: 10000
# # nodes: 10169, # edges: 10000
# torch.Size([10169, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# # sampled nodes: 10265
# # sampled edges: 10000
# # nodes: 10265, # edges: 10000
# torch.Size([10265, 256])
# # sampled nodes: 10256
# # sampled edges: 10000
# # nodes: 10256, # edges: 10000
# torch.Size([10256, 256])
# # sampled nodes: 10286
# # sampled edges: 10000
# # nodes: 10286, # edges: 10000
# torch.Size([10286, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# Epoch 0210 | Loss 0.2750 | Best MRR 0.0145 | Forward 0.0329s | Backward 0.0759s
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10200
# # sampled edges: 10000
# # nodes: 10200, # edges: 10000
# torch.Size([10200, 256])
# # sampled nodes: 10248
# # sampled edges: 10000
# # nodes: 10248, # edges: 10000
# torch.Size([10248, 256])
# # sampled nodes: 10301
# # sampled edges: 10000
# # nodes: 10301, # edges: 10000
# torch.Size([10301, 256])
# # sampled nodes: 10228
# # sampled edges: 10000
# # nodes: 10228, # edges: 10000
# torch.Size([10228, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# # sampled nodes: 10201
# # sampled edges: 10000
# # nodes: 10201, # edges: 10000
# torch.Size([10201, 256])
# # sampled nodes: 10183
# # sampled edges: 10000
# # nodes: 10183, # edges: 10000
# torch.Size([10183, 256])
# # sampled nodes: 10193
# # sampled edges: 10000
# # nodes: 10193, # edges: 10000
# torch.Size([10193, 256])
# Epoch 0220 | Loss 0.2714 | Best MRR 0.0145 | Forward 0.0295s | Backward 0.0748s
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10183
# # sampled edges: 10000
# # nodes: 10183, # edges: 10000
# torch.Size([10183, 256])
# # sampled nodes: 10200
# # sampled edges: 10000
# # nodes: 10200, # edges: 10000
# torch.Size([10200, 256])
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10310
# # sampled edges: 10000
# # nodes: 10310, # edges: 10000
# torch.Size([10310, 256])
# # sampled nodes: 10295
# # sampled edges: 10000
# # nodes: 10295, # edges: 10000
# torch.Size([10295, 256])
# # sampled nodes: 10248
# # sampled edges: 10000
# # nodes: 10248, # edges: 10000
# torch.Size([10248, 256])
# # sampled nodes: 10321
# # sampled edges: 10000
# # nodes: 10321, # edges: 10000
# torch.Size([10321, 256])
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# Epoch 0230 | Loss 0.2680 | Best MRR 0.0145 | Forward 0.0295s | Backward 0.0726s
# # sampled nodes: 10271
# # sampled edges: 10000
# # nodes: 10271, # edges: 10000
# torch.Size([10271, 256])
# # sampled nodes: 10265
# # sampled edges: 10000
# # nodes: 10265, # edges: 10000
# torch.Size([10265, 256])
# # sampled nodes: 10215
# # sampled edges: 10000
# # nodes: 10215, # edges: 10000
# torch.Size([10215, 256])
# # sampled nodes: 10227
# # sampled edges: 10000
# # nodes: 10227, # edges: 10000
# torch.Size([10227, 256])
# # sampled nodes: 10320
# # sampled edges: 10000
# # nodes: 10320, # edges: 10000
# torch.Size([10320, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# # sampled nodes: 10227
# # sampled edges: 10000
# # nodes: 10227, # edges: 10000
# torch.Size([10227, 256])
# # sampled nodes: 10265
# # sampled edges: 10000
# # nodes: 10265, # edges: 10000
# torch.Size([10265, 256])
# # sampled nodes: 10286
# # sampled edges: 10000
# # nodes: 10286, # edges: 10000
# torch.Size([10286, 256])
# # sampled nodes: 10227
# # sampled edges: 10000
# # nodes: 10227, # edges: 10000
# torch.Size([10227, 256])
# Epoch 0240 | Loss 0.2638 | Best MRR 0.0145 | Forward 0.0294s | Backward 0.0741s
# # sampled nodes: 10312
# # sampled edges: 10000
# # nodes: 10312, # edges: 10000
# torch.Size([10312, 256])
# # sampled nodes: 10287
# # sampled edges: 10000
# # nodes: 10287, # edges: 10000
# torch.Size([10287, 256])
# # sampled nodes: 10223
# # sampled edges: 10000
# # nodes: 10223, # edges: 10000
# torch.Size([10223, 256])
# # sampled nodes: 10192
# # sampled edges: 10000
# # nodes: 10192, # edges: 10000
# torch.Size([10192, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10200
# # sampled edges: 10000
# # nodes: 10200, # edges: 10000
# torch.Size([10200, 256])
# # sampled nodes: 10264
# # sampled edges: 10000
# # nodes: 10264, # edges: 10000
# torch.Size([10264, 256])
# Epoch 0250 | Loss 0.2654 | Best MRR 0.0145 | Forward 0.0294s | Backward 0.0753s
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10177
# # sampled edges: 10000
# # nodes: 10177, # edges: 10000
# torch.Size([10177, 256])
# # sampled nodes: 10204
# # sampled edges: 10000
# # nodes: 10204, # edges: 10000
# torch.Size([10204, 256])
# # sampled nodes: 10260
# # sampled edges: 10000
# # nodes: 10260, # edges: 10000
# torch.Size([10260, 256])
# # sampled nodes: 10301
# # sampled edges: 10000
# # nodes: 10301, # edges: 10000
# torch.Size([10301, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10199
# # sampled edges: 10000
# # nodes: 10199, # edges: 10000
# torch.Size([10199, 256])
# # sampled nodes: 10283
# # sampled edges: 10000
# # nodes: 10283, # edges: 10000
# torch.Size([10283, 256])
# # sampled nodes: 10192
# # sampled edges: 10000
# # nodes: 10192, # edges: 10000
# torch.Size([10192, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# Epoch 0260 | Loss 0.2615 | Best MRR 0.0145 | Forward 0.0295s | Backward 0.0757s
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10094
# # sampled edges: 10000
# # nodes: 10094, # edges: 10000
# torch.Size([10094, 256])
# # sampled nodes: 10207
# # sampled edges: 10000
# # nodes: 10207, # edges: 10000
# torch.Size([10207, 256])
# # sampled nodes: 10221
# # sampled edges: 10000
# # nodes: 10221, # edges: 10000
# torch.Size([10221, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10293
# # sampled edges: 10000
# # nodes: 10293, # edges: 10000
# torch.Size([10293, 256])
# Epoch 0270 | Loss 0.2616 | Best MRR 0.0145 | Forward 0.0295s | Backward 0.0745s
# # sampled nodes: 10221
# # sampled edges: 10000
# # nodes: 10221, # edges: 10000
# torch.Size([10221, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10271
# # sampled edges: 10000
# # nodes: 10271, # edges: 10000
# torch.Size([10271, 256])
# # sampled nodes: 10352
# # sampled edges: 10000
# # nodes: 10352, # edges: 10000
# torch.Size([10352, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10327
# # sampled edges: 10000
# # nodes: 10327, # edges: 10000
# torch.Size([10327, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10247
# # sampled edges: 10000
# # nodes: 10247, # edges: 10000
# torch.Size([10247, 256])
# # sampled nodes: 10222
# # sampled edges: 10000
# # nodes: 10222, # edges: 10000
# torch.Size([10222, 256])
# # sampled nodes: 10145
# # sampled edges: 10000
# # nodes: 10145, # edges: 10000
# torch.Size([10145, 256])
# Epoch 0280 | Loss 0.2626 | Best MRR 0.0145 | Forward 0.0294s | Backward 0.0743s
# # sampled nodes: 10210
# # sampled edges: 10000
# # nodes: 10210, # edges: 10000
# torch.Size([10210, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10222
# # sampled edges: 10000
# # nodes: 10222, # edges: 10000
# torch.Size([10222, 256])
# # sampled nodes: 10253
# # sampled edges: 10000
# # nodes: 10253, # edges: 10000
# torch.Size([10253, 256])
# # sampled nodes: 10202
# # sampled edges: 10000
# # nodes: 10202, # edges: 10000
# torch.Size([10202, 256])
# # sampled nodes: 10247
# # sampled edges: 10000
# # nodes: 10247, # edges: 10000
# torch.Size([10247, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10301
# # sampled edges: 10000
# # nodes: 10301, # edges: 10000
# torch.Size([10301, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# Epoch 0290 | Loss 0.2617 | Best MRR 0.0145 | Forward 0.0296s | Backward 0.0752s
# # sampled nodes: 10234
# # sampled edges: 10000
# # nodes: 10234, # edges: 10000
# torch.Size([10234, 256])
# # sampled nodes: 10291
# # sampled edges: 10000
# # nodes: 10291, # edges: 10000
# torch.Size([10291, 256])
# # sampled nodes: 10136
# # sampled edges: 10000
# # nodes: 10136, # edges: 10000
# torch.Size([10136, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# # sampled nodes: 10220
# # sampled edges: 10000
# # nodes: 10220, # edges: 10000
# torch.Size([10220, 256])
# # sampled nodes: 10192
# # sampled edges: 10000
# # nodes: 10192, # edges: 10000
# torch.Size([10192, 256])
# # sampled nodes: 10290
# # sampled edges: 10000
# # nodes: 10290, # edges: 10000
# torch.Size([10290, 256])
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# # sampled nodes: 10173
# # sampled edges: 10000
# # nodes: 10173, # edges: 10000
# torch.Size([10173, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# Epoch 0300 | Loss 0.2589 | Best MRR 0.0145 | Forward 0.0295s | Backward 0.0747s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.017444
# Hits (raw) @ 1: 0.007871
# Hits (raw) @ 3: 0.014941
# Hits (raw) @ 10: 0.030283
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10181
# # sampled edges: 10000
# # nodes: 10181, # edges: 10000
# torch.Size([10181, 256])
# # sampled nodes: 10248
# # sampled edges: 10000
# # nodes: 10248, # edges: 10000
# torch.Size([10248, 256])
# # sampled nodes: 10215
# # sampled edges: 10000
# # nodes: 10215, # edges: 10000
# torch.Size([10215, 256])
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10317
# # sampled edges: 10000
# # nodes: 10317, # edges: 10000
# torch.Size([10317, 256])
# # sampled nodes: 10296
# # sampled edges: 10000
# # nodes: 10296, # edges: 10000
# torch.Size([10296, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# Epoch 0310 | Loss 0.2580 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0756s
# # sampled nodes: 10267
# # sampled edges: 10000
# # nodes: 10267, # edges: 10000
# torch.Size([10267, 256])
# # sampled nodes: 10220
# # sampled edges: 10000
# # nodes: 10220, # edges: 10000
# torch.Size([10220, 256])
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10222
# # sampled edges: 10000
# # nodes: 10222, # edges: 10000
# torch.Size([10222, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# # sampled nodes: 10196
# # sampled edges: 10000
# # nodes: 10196, # edges: 10000
# torch.Size([10196, 256])
# # sampled nodes: 10243
# # sampled edges: 10000
# # nodes: 10243, # edges: 10000
# torch.Size([10243, 256])
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# Epoch 0320 | Loss 0.2585 | Best MRR 0.0174 | Forward 0.0294s | Backward 0.0758s
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10276
# # sampled edges: 10000
# # nodes: 10276, # edges: 10000
# torch.Size([10276, 256])
# # sampled nodes: 10290
# # sampled edges: 10000
# # nodes: 10290, # edges: 10000
# torch.Size([10290, 256])
# # sampled nodes: 10221
# # sampled edges: 10000
# # nodes: 10221, # edges: 10000
# torch.Size([10221, 256])
# # sampled nodes: 10160
# # sampled edges: 10000
# # nodes: 10160, # edges: 10000
# torch.Size([10160, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# # sampled nodes: 10256
# # sampled edges: 10000
# # nodes: 10256, # edges: 10000
# torch.Size([10256, 256])
# # sampled nodes: 10261
# # sampled edges: 10000
# # nodes: 10261, # edges: 10000
# torch.Size([10261, 256])
# Epoch 0330 | Loss 0.2585 | Best MRR 0.0174 | Forward 0.0294s | Backward 0.0745s
# # sampled nodes: 10376
# # sampled edges: 10000
# # nodes: 10376, # edges: 10000
# torch.Size([10376, 256])
# # sampled nodes: 10165
# # sampled edges: 10000
# # nodes: 10165, # edges: 10000
# torch.Size([10165, 256])
# # sampled nodes: 10179
# # sampled edges: 10000
# # nodes: 10179, # edges: 10000
# torch.Size([10179, 256])
# # sampled nodes: 10264
# # sampled edges: 10000
# # nodes: 10264, # edges: 10000
# torch.Size([10264, 256])
# # sampled nodes: 10239
# # sampled edges: 10000
# # nodes: 10239, # edges: 10000
# torch.Size([10239, 256])
# # sampled nodes: 10224
# # sampled edges: 10000
# # nodes: 10224, # edges: 10000
# torch.Size([10224, 256])
# # sampled nodes: 10310
# # sampled edges: 10000
# # nodes: 10310, # edges: 10000
# torch.Size([10310, 256])
# # sampled nodes: 10286
# # sampled edges: 10000
# # nodes: 10286, # edges: 10000
# torch.Size([10286, 256])
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# Epoch 0340 | Loss 0.2518 | Best MRR 0.0174 | Forward 0.0294s | Backward 0.0744s
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10222
# # sampled edges: 10000
# # nodes: 10222, # edges: 10000
# torch.Size([10222, 256])
# # sampled nodes: 10273
# # sampled edges: 10000
# # nodes: 10273, # edges: 10000
# torch.Size([10273, 256])
# # sampled nodes: 10203
# # sampled edges: 10000
# # nodes: 10203, # edges: 10000
# torch.Size([10203, 256])
# # sampled nodes: 10186
# # sampled edges: 10000
# # nodes: 10186, # edges: 10000
# torch.Size([10186, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10263
# # sampled edges: 10000
# # nodes: 10263, # edges: 10000
# torch.Size([10263, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10237
# # sampled edges: 10000
# # nodes: 10237, # edges: 10000
# torch.Size([10237, 256])
# # sampled nodes: 10260
# # sampled edges: 10000
# # nodes: 10260, # edges: 10000
# torch.Size([10260, 256])
# Epoch 0350 | Loss 0.2553 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0749s
# # sampled nodes: 10211
# # sampled edges: 10000
# # nodes: 10211, # edges: 10000
# torch.Size([10211, 256])
# # sampled nodes: 10326
# # sampled edges: 10000
# # nodes: 10326, # edges: 10000
# torch.Size([10326, 256])
# # sampled nodes: 10199
# # sampled edges: 10000
# # nodes: 10199, # edges: 10000
# torch.Size([10199, 256])
# # sampled nodes: 10239
# # sampled edges: 10000
# # nodes: 10239, # edges: 10000
# torch.Size([10239, 256])
# # sampled nodes: 10202
# # sampled edges: 10000
# # nodes: 10202, # edges: 10000
# torch.Size([10202, 256])
# # sampled nodes: 10170
# # sampled edges: 10000
# # nodes: 10170, # edges: 10000
# torch.Size([10170, 256])
# # sampled nodes: 10257
# # sampled edges: 10000
# # nodes: 10257, # edges: 10000
# torch.Size([10257, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10219
# # sampled edges: 10000
# # nodes: 10219, # edges: 10000
# torch.Size([10219, 256])
# # sampled nodes: 10198
# # sampled edges: 10000
# # nodes: 10198, # edges: 10000
# torch.Size([10198, 256])
# Epoch 0360 | Loss 0.2530 | Best MRR 0.0174 | Forward 0.0294s | Backward 0.0749s
# # sampled nodes: 10194
# # sampled edges: 10000
# # nodes: 10194, # edges: 10000
# torch.Size([10194, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10248
# # sampled edges: 10000
# # nodes: 10248, # edges: 10000
# torch.Size([10248, 256])
# # sampled nodes: 10315
# # sampled edges: 10000
# # nodes: 10315, # edges: 10000
# torch.Size([10315, 256])
# # sampled nodes: 10310
# # sampled edges: 10000
# # nodes: 10310, # edges: 10000
# torch.Size([10310, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10296
# # sampled edges: 10000
# # nodes: 10296, # edges: 10000
# torch.Size([10296, 256])
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# # sampled nodes: 10327
# # sampled edges: 10000
# # nodes: 10327, # edges: 10000
# torch.Size([10327, 256])
# # sampled nodes: 10337
# # sampled edges: 10000
# # nodes: 10337, # edges: 10000
# torch.Size([10337, 256])
# Epoch 0370 | Loss 0.2516 | Best MRR 0.0174 | Forward 0.0296s | Backward 0.0751s
# # sampled nodes: 10250
# # sampled edges: 10000
# # nodes: 10250, # edges: 10000
# torch.Size([10250, 256])
# # sampled nodes: 10195
# # sampled edges: 10000
# # nodes: 10195, # edges: 10000
# torch.Size([10195, 256])
# # sampled nodes: 10197
# # sampled edges: 10000
# # nodes: 10197, # edges: 10000
# torch.Size([10197, 256])
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10289
# # sampled edges: 10000
# # nodes: 10289, # edges: 10000
# torch.Size([10289, 256])
# # sampled nodes: 10309
# # sampled edges: 10000
# # nodes: 10309, # edges: 10000
# torch.Size([10309, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10254
# # sampled edges: 10000
# # nodes: 10254, # edges: 10000
# torch.Size([10254, 256])
# # sampled nodes: 10199
# # sampled edges: 10000
# # nodes: 10199, # edges: 10000
# torch.Size([10199, 256])
# Epoch 0380 | Loss 0.2507 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0748s
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10224
# # sampled edges: 10000
# # nodes: 10224, # edges: 10000
# torch.Size([10224, 256])
# # sampled nodes: 10303
# # sampled edges: 10000
# # nodes: 10303, # edges: 10000
# torch.Size([10303, 256])
# # sampled nodes: 10297
# # sampled edges: 10000
# # nodes: 10297, # edges: 10000
# torch.Size([10297, 256])
# # sampled nodes: 10263
# # sampled edges: 10000
# # nodes: 10263, # edges: 10000
# torch.Size([10263, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10296
# # sampled edges: 10000
# # nodes: 10296, # edges: 10000
# torch.Size([10296, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10295
# # sampled edges: 10000
# # nodes: 10295, # edges: 10000
# torch.Size([10295, 256])
# Epoch 0390 | Loss 0.2463 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0751s
# # sampled nodes: 10116
# # sampled edges: 10000
# # nodes: 10116, # edges: 10000
# torch.Size([10116, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10285
# # sampled edges: 10000
# # nodes: 10285, # edges: 10000
# torch.Size([10285, 256])
# # sampled nodes: 10269
# # sampled edges: 10000
# # nodes: 10269, # edges: 10000
# torch.Size([10269, 256])
# # sampled nodes: 10201
# # sampled edges: 10000
# # nodes: 10201, # edges: 10000
# torch.Size([10201, 256])
# # sampled nodes: 10198
# # sampled edges: 10000
# # nodes: 10198, # edges: 10000
# torch.Size([10198, 256])
# # sampled nodes: 10291
# # sampled edges: 10000
# # nodes: 10291, # edges: 10000
# torch.Size([10291, 256])
# # sampled nodes: 10171
# # sampled edges: 10000
# # nodes: 10171, # edges: 10000
# torch.Size([10171, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10203
# # sampled edges: 10000
# # nodes: 10203, # edges: 10000
# torch.Size([10203, 256])
# Epoch 0400 | Loss 0.2480 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0746s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.013970
# Hits (raw) @ 1: 0.003602
# Hits (raw) @ 3: 0.009472
# Hits (raw) @ 10: 0.032684
# # sampled nodes: 10237
# # sampled edges: 10000
# # nodes: 10237, # edges: 10000
# torch.Size([10237, 256])
# # sampled nodes: 10240
# # sampled edges: 10000
# # nodes: 10240, # edges: 10000
# torch.Size([10240, 256])
# # sampled nodes: 10254
# # sampled edges: 10000
# # nodes: 10254, # edges: 10000
# torch.Size([10254, 256])
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# # sampled nodes: 10302
# # sampled edges: 10000
# # nodes: 10302, # edges: 10000
# torch.Size([10302, 256])
# # sampled nodes: 10317
# # sampled edges: 10000
# # nodes: 10317, # edges: 10000
# torch.Size([10317, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10296
# # sampled edges: 10000
# # nodes: 10296, # edges: 10000
# torch.Size([10296, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# # sampled nodes: 10305
# # sampled edges: 10000
# # nodes: 10305, # edges: 10000
# torch.Size([10305, 256])
# Epoch 0410 | Loss 0.2486 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0748s
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# # sampled nodes: 10175
# # sampled edges: 10000
# # nodes: 10175, # edges: 10000
# torch.Size([10175, 256])
# # sampled nodes: 10251
# # sampled edges: 10000
# # nodes: 10251, # edges: 10000
# torch.Size([10251, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10230
# # sampled edges: 10000
# # nodes: 10230, # edges: 10000
# torch.Size([10230, 256])
# # sampled nodes: 10235
# # sampled edges: 10000
# # nodes: 10235, # edges: 10000
# torch.Size([10235, 256])
# # sampled nodes: 10302
# # sampled edges: 10000
# # nodes: 10302, # edges: 10000
# torch.Size([10302, 256])
# # sampled nodes: 10225
# # sampled edges: 10000
# # nodes: 10225, # edges: 10000
# torch.Size([10225, 256])
# # sampled nodes: 10214
# # sampled edges: 10000
# # nodes: 10214, # edges: 10000
# torch.Size([10214, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# Epoch 0420 | Loss 0.2472 | Best MRR 0.0174 | Forward 0.0295s | Backward 0.0755s
# # sampled nodes: 10179
# # sampled edges: 10000
# # nodes: 10179, # edges: 10000
# torch.Size([10179, 256])
# # sampled nodes: 10310
# # sampled edges: 10000
# # nodes: 10310, # edges: 10000
# torch.Size([10310, 256])
# ...
# # sampled nodes: 10202
# # sampled edges: 10000
# # nodes: 10202, # edges: 10000
# torch.Size([10202, 256])
# # sampled nodes: 10199
# # sampled edges: 10000
# # nodes: 10199, # edges: 10000
# torch.Size([10199, 256])
# # sampled nodes: 10162
# # sampled edges: 10000
# # nodes: 10162, # edges: 10000
# torch.Size([10162, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10179
# # sampled edges: 10000
# # nodes: 10179, # edges: 10000
# torch.Size([10179, 256])
# # sampled nodes: 10143
# # sampled edges: 10000
# # nodes: 10143, # edges: 10000
# torch.Size([10143, 256])
# # sampled nodes: 10169
# # sampled edges: 10000
# # nodes: 10169, # edges: 10000
# torch.Size([10169, 256])
# # sampled nodes: 10281
# # sampled edges: 10000
# # nodes: 10281, # edges: 10000
# torch.Size([10281, 256])
# Epoch 5870 | Loss 0.2137 | Best MRR 0.0244 | Forward 0.0302s | Backward 0.0722s
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10237
# # sampled edges: 10000
# # nodes: 10237, # edges: 10000
# torch.Size([10237, 256])
# # sampled nodes: 10260
# # sampled edges: 10000
# # nodes: 10260, # edges: 10000
# torch.Size([10260, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10287
# # sampled edges: 10000
# # nodes: 10287, # edges: 10000
# torch.Size([10287, 256])
# # sampled nodes: 10289
# # sampled edges: 10000
# # nodes: 10289, # edges: 10000
# torch.Size([10289, 256])
# # sampled nodes: 10268
# # sampled edges: 10000
# # nodes: 10268, # edges: 10000
# torch.Size([10268, 256])
# # sampled nodes: 10226
# # sampled edges: 10000
# # nodes: 10226, # edges: 10000
# torch.Size([10226, 256])
# # sampled nodes: 10268
# # sampled edges: 10000
# # nodes: 10268, # edges: 10000
# torch.Size([10268, 256])
# # sampled nodes: 10236
# # sampled edges: 10000
# # nodes: 10236, # edges: 10000
# torch.Size([10236, 256])
# Epoch 5880 | Loss 0.2117 | Best MRR 0.0244 | Forward 0.0294s | Backward 0.0740s
# # sampled nodes: 10290
# # sampled edges: 10000
# # nodes: 10290, # edges: 10000
# torch.Size([10290, 256])
# # sampled nodes: 10142
# # sampled edges: 10000
# # nodes: 10142, # edges: 10000
# torch.Size([10142, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10268
# # sampled edges: 10000
# # nodes: 10268, # edges: 10000
# torch.Size([10268, 256])
# # sampled nodes: 10218
# # sampled edges: 10000
# # nodes: 10218, # edges: 10000
# torch.Size([10218, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# # sampled nodes: 10280
# # sampled edges: 10000
# # nodes: 10280, # edges: 10000
# torch.Size([10280, 256])
# # sampled nodes: 10318
# # sampled edges: 10000
# # nodes: 10318, # edges: 10000
# torch.Size([10318, 256])
# # sampled nodes: 10227
# # sampled edges: 10000
# # nodes: 10227, # edges: 10000
# torch.Size([10227, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# Epoch 5890 | Loss 0.2114 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0728s
# # sampled nodes: 10252
# # sampled edges: 10000
# # nodes: 10252, # edges: 10000
# torch.Size([10252, 256])
# # sampled nodes: 10229
# # sampled edges: 10000
# # nodes: 10229, # edges: 10000
# torch.Size([10229, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10161
# # sampled edges: 10000
# # nodes: 10161, # edges: 10000
# torch.Size([10161, 256])
# # sampled nodes: 10238
# # sampled edges: 10000
# # nodes: 10238, # edges: 10000
# torch.Size([10238, 256])
# # sampled nodes: 10323
# # sampled edges: 10000
# # nodes: 10323, # edges: 10000
# torch.Size([10323, 256])
# # sampled nodes: 10185
# # sampled edges: 10000
# # nodes: 10185, # edges: 10000
# torch.Size([10185, 256])
# # sampled nodes: 10272
# # sampled edges: 10000
# # nodes: 10272, # edges: 10000
# torch.Size([10272, 256])
# # sampled nodes: 10210
# # sampled edges: 10000
# # nodes: 10210, # edges: 10000
# torch.Size([10210, 256])
# Epoch 5900 | Loss 0.2137 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0722s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.023959
# Hits (raw) @ 1: 0.007337
# Hits (raw) @ 3: 0.020945
# Hits (raw) @ 10: 0.053629
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10268
# # sampled edges: 10000
# # nodes: 10268, # edges: 10000
# torch.Size([10268, 256])
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10190
# # sampled edges: 10000
# # nodes: 10190, # edges: 10000
# torch.Size([10190, 256])
# # sampled nodes: 10161
# # sampled edges: 10000
# # nodes: 10161, # edges: 10000
# torch.Size([10161, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10254
# # sampled edges: 10000
# # nodes: 10254, # edges: 10000
# torch.Size([10254, 256])
# # sampled nodes: 10171
# # sampled edges: 10000
# # nodes: 10171, # edges: 10000
# torch.Size([10171, 256])
# # sampled nodes: 10243
# # sampled edges: 10000
# # nodes: 10243, # edges: 10000
# torch.Size([10243, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# Epoch 5910 | Loss 0.2126 | Best MRR 0.0244 | Forward 0.0353s | Backward 0.0752s
# # sampled nodes: 10305
# # sampled edges: 10000
# # nodes: 10305, # edges: 10000
# torch.Size([10305, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# # sampled nodes: 10294
# # sampled edges: 10000
# # nodes: 10294, # edges: 10000
# torch.Size([10294, 256])
# # sampled nodes: 10221
# # sampled edges: 10000
# # nodes: 10221, # edges: 10000
# torch.Size([10221, 256])
# # sampled nodes: 10280
# # sampled edges: 10000
# # nodes: 10280, # edges: 10000
# torch.Size([10280, 256])
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# # sampled nodes: 10153
# # sampled edges: 10000
# # nodes: 10153, # edges: 10000
# torch.Size([10153, 256])
# # sampled nodes: 10223
# # sampled edges: 10000
# # nodes: 10223, # edges: 10000
# torch.Size([10223, 256])
# # sampled nodes: 10291
# # sampled edges: 10000
# # nodes: 10291, # edges: 10000
# torch.Size([10291, 256])
# # sampled nodes: 10227
# # sampled edges: 10000
# # nodes: 10227, # edges: 10000
# torch.Size([10227, 256])
# Epoch 5920 | Loss 0.2162 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0745s
# # sampled nodes: 10230
# # sampled edges: 10000
# # nodes: 10230, # edges: 10000
# torch.Size([10230, 256])
# # sampled nodes: 10210
# # sampled edges: 10000
# # nodes: 10210, # edges: 10000
# torch.Size([10210, 256])
# # sampled nodes: 10255
# # sampled edges: 10000
# # nodes: 10255, # edges: 10000
# torch.Size([10255, 256])
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# # sampled nodes: 10228
# # sampled edges: 10000
# # nodes: 10228, # edges: 10000
# torch.Size([10228, 256])
# # sampled nodes: 10274
# # sampled edges: 10000
# # nodes: 10274, # edges: 10000
# torch.Size([10274, 256])
# # sampled nodes: 10351
# # sampled edges: 10000
# # nodes: 10351, # edges: 10000
# torch.Size([10351, 256])
# # sampled nodes: 10178
# # sampled edges: 10000
# # nodes: 10178, # edges: 10000
# torch.Size([10178, 256])
# # sampled nodes: 10233
# # sampled edges: 10000
# # nodes: 10233, # edges: 10000
# torch.Size([10233, 256])
# # sampled nodes: 10278
# # sampled edges: 10000
# # nodes: 10278, # edges: 10000
# torch.Size([10278, 256])
# Epoch 5930 | Loss 0.2122 | Best MRR 0.0244 | Forward 0.0294s | Backward 0.0754s
# # sampled nodes: 10245
# # sampled edges: 10000
# # nodes: 10245, # edges: 10000
# torch.Size([10245, 256])
# # sampled nodes: 10265
# # sampled edges: 10000
# # nodes: 10265, # edges: 10000
# torch.Size([10265, 256])
# # sampled nodes: 10268
# # sampled edges: 10000
# # nodes: 10268, # edges: 10000
# torch.Size([10268, 256])
# # sampled nodes: 10304
# # sampled edges: 10000
# # nodes: 10304, # edges: 10000
# torch.Size([10304, 256])
# # sampled nodes: 10276
# # sampled edges: 10000
# # nodes: 10276, # edges: 10000
# torch.Size([10276, 256])
# # sampled nodes: 10253
# # sampled edges: 10000
# # nodes: 10253, # edges: 10000
# torch.Size([10253, 256])
# # sampled nodes: 10367
# # sampled edges: 10000
# # nodes: 10367, # edges: 10000
# torch.Size([10367, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10213
# # sampled edges: 10000
# # nodes: 10213, # edges: 10000
# torch.Size([10213, 256])
# # sampled nodes: 10323
# # sampled edges: 10000
# # nodes: 10323, # edges: 10000
# torch.Size([10323, 256])
# Epoch 5940 | Loss 0.2133 | Best MRR 0.0244 | Forward 0.0296s | Backward 0.0726s
# # sampled nodes: 10219
# # sampled edges: 10000
# # nodes: 10219, # edges: 10000
# torch.Size([10219, 256])
# # sampled nodes: 10326
# # sampled edges: 10000
# # nodes: 10326, # edges: 10000
# torch.Size([10326, 256])
# # sampled nodes: 10181
# # sampled edges: 10000
# # nodes: 10181, # edges: 10000
# torch.Size([10181, 256])
# # sampled nodes: 10213
# # sampled edges: 10000
# # nodes: 10213, # edges: 10000
# torch.Size([10213, 256])
# # sampled nodes: 10311
# # sampled edges: 10000
# # nodes: 10311, # edges: 10000
# torch.Size([10311, 256])
# # sampled nodes: 10275
# # sampled edges: 10000
# # nodes: 10275, # edges: 10000
# torch.Size([10275, 256])
# # sampled nodes: 10247
# # sampled edges: 10000
# # nodes: 10247, # edges: 10000
# torch.Size([10247, 256])
# # sampled nodes: 10224
# # sampled edges: 10000
# # nodes: 10224, # edges: 10000
# torch.Size([10224, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10335
# # sampled edges: 10000
# # nodes: 10335, # edges: 10000
# torch.Size([10335, 256])
# Epoch 5950 | Loss 0.2154 | Best MRR 0.0244 | Forward 0.0294s | Backward 0.0716s
# # sampled nodes: 10185
# # sampled edges: 10000
# # nodes: 10185, # edges: 10000
# torch.Size([10185, 256])
# # sampled nodes: 10323
# # sampled edges: 10000
# # nodes: 10323, # edges: 10000
# torch.Size([10323, 256])
# # sampled nodes: 10341
# # sampled edges: 10000
# # nodes: 10341, # edges: 10000
# torch.Size([10341, 256])
# # sampled nodes: 10203
# # sampled edges: 10000
# # nodes: 10203, # edges: 10000
# torch.Size([10203, 256])
# # sampled nodes: 10332
# # sampled edges: 10000
# # nodes: 10332, # edges: 10000
# torch.Size([10332, 256])
# # sampled nodes: 10270
# # sampled edges: 10000
# # nodes: 10270, # edges: 10000
# torch.Size([10270, 256])
# # sampled nodes: 10273
# # sampled edges: 10000
# # nodes: 10273, # edges: 10000
# torch.Size([10273, 256])
# # sampled nodes: 10262
# # sampled edges: 10000
# # nodes: 10262, # edges: 10000
# torch.Size([10262, 256])
# # sampled nodes: 10233
# # sampled edges: 10000
# # nodes: 10233, # edges: 10000
# torch.Size([10233, 256])
# # sampled nodes: 10188
# # sampled edges: 10000
# # nodes: 10188, # edges: 10000
# torch.Size([10188, 256])
# Epoch 5960 | Loss 0.2122 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0729s
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10266
# # sampled edges: 10000
# # nodes: 10266, # edges: 10000
# torch.Size([10266, 256])
# # sampled nodes: 10341
# # sampled edges: 10000
# # nodes: 10341, # edges: 10000
# torch.Size([10341, 256])
# # sampled nodes: 10216
# # sampled edges: 10000
# # nodes: 10216, # edges: 10000
# torch.Size([10216, 256])
# # sampled nodes: 10161
# # sampled edges: 10000
# # nodes: 10161, # edges: 10000
# torch.Size([10161, 256])
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10170
# # sampled edges: 10000
# # nodes: 10170, # edges: 10000
# torch.Size([10170, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10192
# # sampled edges: 10000
# # nodes: 10192, # edges: 10000
# torch.Size([10192, 256])
# # sampled nodes: 10242
# # sampled edges: 10000
# # nodes: 10242, # edges: 10000
# torch.Size([10242, 256])
# Epoch 5970 | Loss 0.2141 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0732s
# # sampled nodes: 10347
# # sampled edges: 10000
# # nodes: 10347, # edges: 10000
# torch.Size([10347, 256])
# # sampled nodes: 10208
# # sampled edges: 10000
# # nodes: 10208, # edges: 10000
# torch.Size([10208, 256])
# # sampled nodes: 10206
# # sampled edges: 10000
# # nodes: 10206, # edges: 10000
# torch.Size([10206, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10277
# # sampled edges: 10000
# # nodes: 10277, # edges: 10000
# torch.Size([10277, 256])
# # sampled nodes: 10239
# # sampled edges: 10000
# # nodes: 10239, # edges: 10000
# torch.Size([10239, 256])
# # sampled nodes: 10307
# # sampled edges: 10000
# # nodes: 10307, # edges: 10000
# torch.Size([10307, 256])
# # sampled nodes: 10212
# # sampled edges: 10000
# # nodes: 10212, # edges: 10000
# torch.Size([10212, 256])
# # sampled nodes: 10349
# # sampled edges: 10000
# # nodes: 10349, # edges: 10000
# torch.Size([10349, 256])
# Epoch 5980 | Loss 0.2101 | Best MRR 0.0244 | Forward 0.0294s | Backward 0.0744s
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10271
# # sampled edges: 10000
# # nodes: 10271, # edges: 10000
# torch.Size([10271, 256])
# # sampled nodes: 10258
# # sampled edges: 10000
# # nodes: 10258, # edges: 10000
# torch.Size([10258, 256])
# # sampled nodes: 10241
# # sampled edges: 10000
# # nodes: 10241, # edges: 10000
# torch.Size([10241, 256])
# # sampled nodes: 10147
# # sampled edges: 10000
# # nodes: 10147, # edges: 10000
# torch.Size([10147, 256])
# # sampled nodes: 10233
# # sampled edges: 10000
# # nodes: 10233, # edges: 10000
# torch.Size([10233, 256])
# # sampled nodes: 10196
# # sampled edges: 10000
# # nodes: 10196, # edges: 10000
# torch.Size([10196, 256])
# # sampled nodes: 10273
# # sampled edges: 10000
# # nodes: 10273, # edges: 10000
# torch.Size([10273, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10232
# # sampled edges: 10000
# # nodes: 10232, # edges: 10000
# torch.Size([10232, 256])
# Epoch 5990 | Loss 0.2125 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0746s
# # sampled nodes: 10302
# # sampled edges: 10000
# # nodes: 10302, # edges: 10000
# torch.Size([10302, 256])
# # sampled nodes: 10269
# # sampled edges: 10000
# # nodes: 10269, # edges: 10000
# torch.Size([10269, 256])
# # sampled nodes: 10151
# # sampled edges: 10000
# # nodes: 10151, # edges: 10000
# torch.Size([10151, 256])
# # sampled nodes: 10178
# # sampled edges: 10000
# # nodes: 10178, # edges: 10000
# torch.Size([10178, 256])
# # sampled nodes: 10231
# # sampled edges: 10000
# # nodes: 10231, # edges: 10000
# torch.Size([10231, 256])
# # sampled nodes: 10259
# # sampled edges: 10000
# # nodes: 10259, # edges: 10000
# torch.Size([10259, 256])
# # sampled nodes: 10203
# # sampled edges: 10000
# # nodes: 10203, # edges: 10000
# torch.Size([10203, 256])
# # sampled nodes: 10210
# # sampled edges: 10000
# # nodes: 10210, # edges: 10000
# torch.Size([10210, 256])
# # sampled nodes: 10246
# # sampled edges: 10000
# # nodes: 10246, # edges: 10000
# torch.Size([10246, 256])
# # sampled nodes: 10240
# # sampled edges: 10000
# # nodes: 10240, # edges: 10000
# torch.Size([10240, 256])
# Epoch 6000 | Loss 0.2132 | Best MRR 0.0244 | Forward 0.0295s | Backward 0.0728s
# start eval
# DGLGraph(num_nodes=20518, num_edges=59542,
#          ndata_schemes={}
#          edata_schemes={})
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# batch 0 / 8
# batch 1 / 8
# batch 2 / 8
# batch 3 / 8
# batch 4 / 8
# batch 5 / 8
# batch 6 / 8
# batch 7 / 8
# MRR (raw): 0.022362
# Hits (raw) @ 1: 0.006804
# Hits (raw) @ 3: 0.018276
# Hits (raw) @ 10: 0.047225
